# %%
from scipy import signal
import matplotlib.pyplot as plt

# %% [markdown]
# # Moving Average

# %%
ma3=signal.TransferFunction([1/4, 1/4, 1/4,1/4],1,  dt=1)

# %%
ma3
# Out:
# TransferFunctionDiscrete(
# array([0.25, 0.25, 0.25, 0.25]),
# array([1.]),
# dt: 1
# )

# %%
ma3.to_zpk()
# Out:
# ZerosPolesGainDiscrete(
# array([-1.00000000e+00+0.j, -7.77156117e-16+1.j, -7.77156117e-16-1.j]),
# array([], dtype=float64),
# np.float64(0.25),
# dt: 1
# )

# %%
w, H = signal.dfreqresp(ma3)

# %%
plt.figure()
plt.plot(H.real, H.imag, "b")
plt.plot(H.real, -H.imag, "r")
plt.show()

# %%
w, mag, phase = signal.dbode(ma3)

# %%
plt.figure()
plt.semilogx(w, mag)    # Bode magnitude plot
plt.figure()
plt.semilogx(w, phase)  # Bode phase plot
plt.show()

# %% [markdown]
# # Diff

# %%
diff_1=signal.TransferFunction([1, -1],1,  dt=1)

# %%
diff_1
# Out:
# TransferFunctionDiscrete(
# array([ 1., -1.]),
# array([1.]),
# dt: 1
# )

# %%
diff_1.to_zpk()
# Out:
# ZerosPolesGainDiscrete(
# array([1.]),
# array([], dtype=float64),
# np.float64(1.0),
# dt: 1
# )

# %%
w1, H1 = signal.dfreqresp(diff_1)

# %%
plt.figure()
plt.plot(H1.real, H1.imag, "b")
plt.plot(H1.real, -H1.imag, "r")
plt.show()

# %%
w1, mag1, phase1 = signal.dbode(diff_1)
# Out:
# /usr/lib/python3/dist-packages/scipy/signal/_ltisys.py:3516: RuntimeWarning: divide by zero encountered in log10
#   mag = 20.0 * np.log10(abs(y))

# %%
plt.figure()
plt.semilogx(w1, mag1)    # Bode magnitude plot
plt.figure()
plt.semilogx(w1, phase1)  # Bode phase plot
plt.show()
